# %%
import numpy as np
import pandas as pd
from erddapy import ERDDAP

# %%
e = ERDDAP(
    server='https://uhslc.soest.hawaii.edu/opendap/rqds/',
    protocol='opendap'
)

e.

# %%
df = e.to_pandas()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-4efa1fa05549> in <module>
# ----> 1 df = e.to_pandas()
#
# ~/opt/anaconda3/envs/pangeo/lib/python3.8/site-packages/erddapy/erddapy.py in to_pandas(self, **kw)
#     545         """
#     546         response = kw.pop("response", "csvp")
# --> 547         url = self.get_download_url(response=response, **kw)
#     548         data = urlopen(url, auth=self.auth, **self.requests_kwargs)
#     549         return pd.read_csv(data, **kw)
#
# ~/opt/anaconda3/envs/pangeo/lib/python3.8/site-packages/erddapy/erddapy.py in get_download_url(self, dataset_id, protocol, variables, dim_names, response, constraints, relative_constraints, **kwargs)
#     468
#     469         if not dataset_id:
# --> 470             raise ValueError(f"Please specify a valid `dataset_id`, got {dataset_id}")
#     471
# ...

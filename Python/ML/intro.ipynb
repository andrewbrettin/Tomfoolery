# %% [markdown]
# ## Contents
# * [Markdown cell](#Markdown-cell-type)

# %%
import numpy as np
import xarray as xr 
import matplotlib.pyplot as plt

# %%
a = 2

# %% [markdown]
# # Markdown cell type
# $$
# e^{i\theta} = \cos{\theta} + i \sin{\theta}
# $$

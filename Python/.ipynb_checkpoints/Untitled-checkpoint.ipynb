# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

# %%
rands = np.random.rand(100)

# %%
cdf = lambda x : 0.5*(1 + erf(x))
# Out:
# 1.0

# %%
xs = np.linspace(-3,3)
plt.plot(xs, 0.5*(1 + erf(xs)))

# %%
# Need inverse of the error function

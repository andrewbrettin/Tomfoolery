# %%
import numpy as np
import multiprocessing

# %%
array = np.random.rand(1000, 1000)

# %%
def foo(n):
    return np.mean(np.arange(0, n)**2)

# %%
pool = multiprocessing.Pool()

out = pool.map(foo, [0, 1, 2, 3])

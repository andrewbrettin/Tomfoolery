# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
darr1 = xr.DataArray(
    2*np.random.rand(5, 100) + 0.05*np.arange(100),
    dims=("member", 'time'),
    coords={'time': np.arange(100)}
)

darr2 = xr.DataArray(
    2*np.random.rand(5, 100) + 0.02*np.arange(100),
    dims=("member", 'time'),
    coords={'time': np.arange(100)}
)

darr_list = [darr1, darr2]

# %%
ensemble_mean = darr.mean(dim='member')

# %%
fig, ax = plt.subplots()
for member in darr.member:
    darr.sel(member=member).plot(ax=ax, color=(0.7,0.7,0.7))
ensemble_mean.plot(ax=ax, label='ensemble mean')

ax.legend()

# %%
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']

ensemble_spread = darr.std(dim='member')

for darr in darr_list:
    fig, ax = plt.subplots()
    ensemble_mean.plot(ax=ax, color='tab:blue')
    ax.fill_between(ensemble_mean.time, 
                    ensemble_mean-ensemble_spread, 
                    ensemble_mean+ensemble_spread, 
                   alpha=0.2)

# %%
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']
# Out:
# ['tab:red']
